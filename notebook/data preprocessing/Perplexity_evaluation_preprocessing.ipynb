# %% [markdown]
# `<unused0>요리명<unused1><unused2>재료1$재료2$재료$<unused3><unused4>레시피내용<unused5>` 형태에서 `레시피내용`만 있도록 형식 변환

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Perplexity metric evaluation 형식으로 변환

# %%
f = open("/content/drive/MyDrive/11_recipe_generator/data/test.txt", 'r')
k = open('test_metric.txt', 'w')

lines = f.readlines()
for line in lines:
  to_write = ''
  end = line.find('<unused4>')
  to_write += line[end+9:].replace('<unused5>','')
  k.writelines(to_write)
f.close()
k.close()
